# %%
# !nvidia-smi
# Out:
# Sun Oct 29 13:12:34 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 kB 5.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %% [markdown]
# ##Aplicar Modelos em Imagens e Vídeos

# %%
# !yolo task=segment mode=predict model=/content/yolov8n.pt conf=0.25 source="casa.mp4" save=True
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 123MB/s]
# WARNING ⚠️ conflicting 'task=segment' passed with 'task=detect' model. Ignoring 'task=segment' and updating to 'task=detect' to match model.
# Ultralytics YOLOv8.0.202 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# video 1/1 (1/1361) /content/casa.mp4: 640x384 1 person, 154.5ms
# video 1/1 (2/1361) /content/casa.mp4: 640x384 1 person, 6.9ms
# video 1/1 (3/1361) /content/casa.mp4: 640x384 1 person, 7.7ms
# video 1/1 (4/1361) /content/casa.mp4: 640x384 1 person, 8.6ms
# video 1/1 (5/1361) /content/casa.mp4: 640x384 1 person, 6.5ms
# video 1/1 (6/1361) /content/casa.mp4: 640x384 1 person, 6.1ms
# video 1/1 (7/1361) /content/casa.mp4: 640x384 1 person, 6.2ms
# video 1/1 (8/1361) /content/casa.mp4: 640x384 1 person, 6.1ms
# video 1/1 (9/1361) /content/casa.mp4: 640x384 1 person, 6.1ms
# ...

# %%
from IPython.display import Video

Video('/content/runs/detect/predict/casa.avi')
# Out:
# <video src="/content/runs/detect/predict/casa.avi" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
