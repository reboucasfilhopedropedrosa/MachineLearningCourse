# %% [markdown]
# ##YOLO v8 Detection and Segmentation

# %%
# !nvidia-smi
# Out:
# Sun Oct 29 13:11:46 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 kB 9.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %% [markdown]
# ##Aplicar Modelos em Imagens e Vídeos

# %%
# !yolo task=detectar \ mode=prever \ model=yolov8n.pt \ source="image.jpg"
# Para utilizá-lo basta inserir os seguintes comandos:
# task in [detect, classify, segment]
# mode in [train, predict, val, export]
# model as an uninitialized .yaml or as a previously trained .pt file
# Source as the path/to/data

# !yolo task=segment mode=predict model=/content/yolov8l-seg.pt conf=0.25 source="cavalospessoas.jpeg" save=True
# Out:
# ...
# 100% 88.1M/88.1M [00:01<00:00, 71.0MB/s]
# Ultralytics YOLOv8.0.201 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l-seg summary (fused): 295 layers, 45973568 parameters, 0 gradients, 220.5 GFLOPs
#
# image 1/1 /content/cavalospessoas.jpeg: 448x640 2 persons, 2 horses, 105.0ms
# Speed: 13.5ms preprocess, 105.0ms inference, 46.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import Image
Image('/content/runs/segment/predict/cavalospessoas.jpeg')
