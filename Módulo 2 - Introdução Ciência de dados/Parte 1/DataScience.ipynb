# %% [markdown]
# # Ciência de dados utilizando Python

# %% [markdown]
# ## Conhecendo o dataset

# %% [markdown]
# ![iris-dataset.png](data:image/png;base64,...)

# %% [markdown]
# ## Importando bibliotecas

# %%
import pandas as pd
import sklearn
import numpy as np
from sklearn.datasets import load_iris

# %% [markdown]
# ## Carregando os dados e preparando os dados

# %%
data = load_iris()
dados = data.data
target = data.target

# %%
dataframe = pd.DataFrame(dados,columns= ['Sepal-Length','Sepal-Width','Petal-Length','Petal-Width'])
dataframe['Especie'] = target
dataframe
# Out:
#      Sepal-Length  Sepal-Width  Petal-Length  Petal-Width  Especie
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
def enconde_species(specie):
  if specie == 0 :
    return 'Setosa'
  elif specie == 1:
    return 'Versicolor'
  elif specie == 2:
    return 'Virginica'

dataframe.Especie = dataframe.Especie.apply(enconde_species)

# %%
dataframe
# Out:
#      Sepal-Length  Sepal-Width  Petal-Length  Petal-Width    Especie
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Análise estatística

# %% [markdown]
# ### Resumo rápido do dataframe

# %%
dataframe.describe()
# Out:
#        Sepal-Length  Sepal-Width  Petal-Length  Petal-Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# #### Conclusões primárias
# - Número de Observações: Cada característica tem 150 observações.
#
# - Média: As médias das características são aproximadamente 5.84 para o comprimento da sépala, 3.06 para a largura da sépala, 3.76 para o comprimento da pétala e 1.20 para a largura da pétala.
#
# - Desvio Padrão: Os desvios padrão são cerca de 0.83 para o comprimento da sépala, 0.44 para a largura da sépala, 1.77 para o comprimento da pétala e 0.76 para a largura da pétala.
#
# - Valores Mínimos: Os valores mínimos observados são 4.3 para o comprimento da sépala, 2.0 para a largura da sépala, 1.0 para o comprimento da pétala e 0.1 para a largura da pétala.
#
# - Primeiro Quartil (25%): 25% das observações estão abaixo de 5.1 para o comprimento da sépala, 2.8 para a largura da sépala, 1.6 para o comprimento da pétala e 0.3 para a largura da pétala.
#
# - Mediana (50%): A mediana (valor no meio) é 5.8 para o comprimento da sépala, 3.0 para a largura da sépala, 4.35 para o comprimento da pétala e 1.3 para a largura da pétala.
#
# - Terceiro Quartil (75%): 75% das observações estão abaixo de 6.4 para o comprimento da sépala, 3.3 para a largura da sépala, 5.1 para o comprimento da pétala e 1.8 para a largura da pétala.
#
# - Valores Máximos: Os valores máximos observados são 7.9 para o comprimento da sépala, 4.4 para a largura da sépala, 6.9 para o comprimento da pétala e 2.5 para a largura da pétala.

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal-Length  150 non-null    float64
#  1   Sepal-Width   150 non-null    float64
#  2   Petal-Length  150 non-null    float64
#  3   Petal-Width   150 non-null    float64
#  4   Especie       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ### Como se da a distribuição dos atributos das flores?

# %%
dataframe['Sepal-Length'].hist()
# Out:
# <Axes: >

# %%
dataframe['Sepal-Width'].hist()
# Out:
# <Axes: >

# %%
dataframe['Petal-Length'].hist()
# Out:
# <Axes: >

# %%
dataframe['Petal-Width'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### Quantas amostras de cada especie de planta temos no dataset?

# %%
import seaborn as sns
sns.catplot(dataframe, x='Especie', kind='count')

# %% [markdown]
# ### Existem outilers?

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
sns.boxplot(data=dataframe[['Sepal-Length',	'Sepal-Width',	'Petal-Length',	'Petal-Width']])
plt.title('Boxplot das Colunas do Dataset Iris')
plt.xlabel('Características')
plt.ylabel('Valores')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Como se da a relação do comprimento da sepala pela largura da sepala?

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=dataframe, x='Sepal-Length', y='Sepal-Width', hue='Especie')
plt.title('Sepal-Length vs Sepal-Width')
plt.show()

# %% [markdown]
# Como se da a relação do comprimento da
# petala pela largura da petala?

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=dataframe, x='Petal-Length', y='Petal-Width', hue='Especie')
plt.title('Petal-Length vs Petal-Width')
plt.show()

# %% [markdown]
# Como se da a relação do comprimento da sepala pelo comprimento da petala?

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=dataframe, x='Sepal-Length', y='Petal-Length', hue='Especie')
plt.title('Sepal-Length vs Petal-Length')
plt.show()

# %% [markdown]
# Como se da a relação da largura da sepala pel largura da petala?

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=dataframe, x='Sepal-Width', y='Petal-Width', hue='Especie')
plt.title('Sepal-Width vs Petal-Width')
plt.show()

# %% [markdown]
# ## Correlação
# O quanto uma variavel é correlata de outra. Se uma cresce a outra cresce, diminui ou não acontece nada?
# ## Formula:
# ![correlacao-1.webp](data:image/webp;base64,...)

# %%
dataframe.corr()
# Out:
# <ipython-input-18-7707f071ecc0>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataframe.corr()
#               Sepal-Length  Sepal-Width  Petal-Length  Petal-Width
# Sepal-Length      1.000000    -0.117570      0.871754     0.817941
# Sepal-Width      -0.117570     1.000000     -0.428440    -0.366126
# Petal-Length      0.871754    -0.428440      1.000000     0.962865
# Petal-Width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.regplot(data = dataframe, x = 'Petal-Length', y = 'Sepal-Length')
# Out:
# <Axes: xlabel='Petal-Length', ylabel='Sepal-Length'>

# %%
sns.regplot(data = dataframe, x = 'Sepal-Width', y = 'Petal-Length')
# Out:
# <Axes: xlabel='Sepal-Width', ylabel='Petal-Length'>
